# %% [markdown]
# Semi-Isomorphism Test

# %%
import networkx as nx

def is_semi_isomorphism(A1, A2):
    
    """"
    Tests if two DFAs A1 = (Q1, Σ1, τ1, (qs)1, F1) and A2 = (Q2, Σ2, τ2, (qs)2, F2) 
    are semi-isomorphic, for this to occur if there exists two bijections:
    1) f: Q1 → Q2 and 2) g: Σ1 → Σ2

    where 
    τ2(f(q), g(a)) = f(τ1(q,a)) for all q ∈ Q1 and all a ∈ Σ1
    """

    """
    Input for the function is two DFAs (A1, A2) and function will return a boolean output
    (True or False) depending on whether the two DFAs ar semi-isomorphic.

    Q is some set of finite states (python type - set)
    Σ is some finite alphabet (python type - set)
    τ is a transition function τ: Q x Σ → Q (python type - dict)
    qs is a start state (python type - int)
    F ⊆ Q is a set of final states (python type - set)
    """
    # Obtaining values from input

    Q1, sigma1, tau1, qs1, F1 = A1
    Q2, sigma2, tau2, qs2, F2 = A2

    # Checking if |Q1| = |Q2| and |Σ1| = |Σ2|
    # If the state sets and alphabets have different sizes no bijection can exist
    if len(Q1) != len(Q2) or len(sigma1) != len(sigma2):
        return False, None, None

    # Convert AFDs to a directed graph on NetworkX for easier use
    G1 = nx.MultiDiGraph()
    for q1 in Q1:
        for a1 in sigma1:
            G1.add_edge(q1, tau1[(q1, a1)], label = a1)


    G2 = nx.MultiDiGraph()
    for q2 in Q2:
        G2.add_node(q2)
        for a2 in sigma2:
            G2.add_edge(q2, tau2[(q2, a2)], label = a2)

    # We assume that in each graph there is one state/node from which all other nodes are reachable.
    # From the SCCC functionality in NetworkX, in one single SCC, properties are inherited since they are all connected,
    # therefore, if there is one SCC which can reach every other SCC our node is in this SCC
    # We can then draw an semi-isomorphisms between these SCCs

    sccs1 = list(nx.strongly_connected_components(G1))
    sccs2 = list(nx.strongly_connected_components(G2))

    # Obtain a condensation of G1 which is the graph of the SCCs

    C1 = nx.condensation(G1, scc = sccs1)
    C2 = nx.condensation(G2, scc = sccs2)
    
    reaching_states1 = []
    reaching_states2 = []

    
    for node in C1.nodes():
        reachable = nx.descendants(C1, node)
        if len(reachable) == len(C1.nodes()) - 1:
            reaching_states1.extend(sccs1[node])

    for node in C2.nodes():
        reachable = nx.descendants(C2, node)
        if len(reachable) == len(C2.nodes()) - 1:
            reaching_states2.extend(sccs2[node])

    # We set up an isomorphism between the sets of states which reach every other state
    # for both A1 and A2, and that is the root of the semi-isomorphism.
    # From this we take pairs of (root1, root2) where root1 is a state
    # which can reach every state of A1 and similarly for root2.
    # We try to establish f(root1) = root2 as an initial mapping,
    # we then try to establish the rest of f and g by continuing the previous transitions.
    # If no combination is possible then no semi-isomorphism exists.
    # Since it is a semi-isomorphism we don't care about starting states, hence
    # the initial mapping of f isn't determined by qs — we try all initial root pairings.
    
    for root1 in reaching_states1:
        for root2 in reaching_states2:

            # Initial mapping, we know one mapping from the SCC
            # g starts empty as we don't know anything about the alphabet mapping yet
            f = {root1: root2}
            g = {}

            queue = [root1]
            visited = {root1}
            check = True

            for q in queue:
                fq = f[q]
                for a in sigma1:
                    q_real = tau1[(q, a)] # where A1 goes from q on symbol a

                    if a in g and q_real in f: # Case 1: we already know both g(a) and f(q_real)
                        if tau2[(fq, g[a])] != f[q_real]:
                            print(q_real)
                            print(f[q_real])
                            print(tau2[(fq, g[a])])
                            print(f)
                            print(g)
                            check = False
                            break

                    elif a in g and q_real not in f: # Case 2: we know g(a) but not f(q_real)
                        target = tau2[(fq, g[a])]
                        if target in f.values():
                            check = False
                            print(q_real)
                            print(f[q_real])
                            print(tau2[(fq, g[a])])
                            print(f)
                            print(g)
                            break
                        f[q_real] = target
                        if q_real not in visited:
                            queue.append(q_real)
                            visited.add(q_real)
                                
                    elif a not in g and q_real in f: #  Case we know f(q_real) but not g(a)
                        found = False
                        for b in sigma2:
                            if b not in g.values() and tau2[(fq, b)] == f[q_real]:
                                g[a] = b
                                found = True
                                break
                        if not found:
                            print(q_real)
                            print(f[q_real])
                            print(tau2[(fq, g[a])])
                            print(f)
                            print(g)
                            check = False
                            break
                            
                    else: # Case 4: we know neither g(a) nor f(q_real)
                        found = False
                        for b in sigma2:
                            if b not in g.values() and tau2[(fq, b)] not in f.values():
                                f[q_real] = tau2[(fq, b)]
                                g[a] = b
                                if q_real not in visited:
                                    queue.append(q_real)
                                    visited.add(q_real)
                                found = True
                                break
                        if not found:
                            print(q_real)
                            print(f[q_real])
                            print(tau2[(fq, g[a])])
                            print(f)
                            print(g)
                            check = False
                            break

                if not check:
                    break

            if check and len(set(f.values())) == len(Q1) and len(set(g.values())) == len(sigma1):
                return True, f, g

    return False, None, None

# %%
from itertools import product
import networkx as nx

def is_semi_isomorphism(A1, A2):
    """
    Tests if two DFAs A1 = (Q1, Σ1, τ1, qs1, F1) and A2 = (Q2, Σ2, τ2, qs2, F2)
    are semi-isomorphic.

    Semi-isomorphism requires bijections f: Q1 → Q2 and g: Σ1 → Σ2 such that:
        τ2(f(q), g(a)) = f(τ1(q, a))  for all q ∈ Q1, a ∈ Σ1

    Start states and final states are ignored.
    We are guaranteed that in each DFA there is exactly one state
    that can reach all other states.
    """

    Q1, sigma1, tau1, qs1, F1 = A1
    Q2, sigma2, tau2, qs2, F2 = A2

    # If sizes differ, no bijection can exist
    if len(Q1) != len(Q2) or len(sigma1) != len(sigma2):
        return False, None, None

    # Build directed graphs for SCC analysis
    G1 = nx.MultiDiGraph()
    for q in Q1:
        for a in sigma1:
            G1.add_edge(q, tau1[(q, a)], label=a)

    G2 = nx.MultiDiGraph()
    for q in Q2:
        for a in sigma2:
            G2.add_edge(q, tau2[(q, a)], label=a)

    # Compute SCCs and their condensations
    sccs1 = list(nx.strongly_connected_components(G1))
    sccs2 = list(nx.strongly_connected_components(G2))

    C1 = nx.condensation(G1, scc=sccs1)
    C2 = nx.condensation(G2, scc=sccs2)

    # Find the unique SCC that can reach all other SCCs
    # We are guaranteed exactly one such SCC exists in each DFA
    # Any state inside that SCC is a valid BFS root since:
    #   - within the SCC every state reaches every other state
    #   - the SCC reaches all other SCCs
    #   - so any state in it can reach all states in Q1
    reaching_states1 = []
    reaching_states2 = []

    for node in C1.nodes():
        reachable = nx.descendants(C1, node)
        if len(reachable) == len(C1.nodes()) - 1:
            reaching_states1.extend(sccs1[node])

    for node in C2.nodes():
        reachable = nx.descendants(C2, node)
        if len(reachable) == len(C2.nodes()) - 1:
            reaching_states2.extend(sccs2[node])

    # Try every pairing of (root1, root2) as the seed of f
    # We try all pairings because semi-isomorphism does not fix start states
    for root1 in reaching_states1:
        for root2 in reaching_states2:

            # Seed f with root1 → root2, g is unknown to start
            f = {root1: root2}
            g = {}

            # BFS over states of A1, propagating f and g as we go
            queue = [root1]
            visited = {root1}
            i = 0
            check = True

            while i < len(queue):
                q = queue[i]
                i += 1
                fq = f[q]

                for a in sigma1:
                    q_next = tau1[(q, a)]

                    # Case 1: both g(a) and f(q_next) already known
                    # Just verify the transition condition holds
                    if a in g and q_next in f:
                        if tau2[(fq, g[a])] != f[q_next]:
                            check = False
                            break

                    # Case 2: g(a) known, f(q_next) not yet set
                    # Deduce f(q_next) from the transition condition
                    elif a in g and q_next not in f:
                        target = tau2[(fq, g[a])]
                        # target must not already be used by f (injectivity)
                        if target in f.values():
                            check = False
                            break
                        f[q_next] = target
                        if q_next not in visited:
                            queue.append(q_next)
                            visited.add(q_next)

                    # Case 3: f(q_next) known, g(a) not yet set
                    # Find a free b in Σ2 such that τ2(f(q), b) = f(q_next)
                    elif a not in g and q_next in f:
                        found = False
                        for b in sigma2:
                            if b not in g.values() and tau2[(fq, b)] == f[q_next]:
                                g[a] = b
                                found = True
                                break
                        if not found:
                            check = False
                            break

                    # Case 4: neither g(a) nor f(q_next) known
                    # Freely pick any valid (b, target) pair
                    # Note: greedy choice here — no backtracking
                    else:
                        found = False
                        for b in sigma2:
                            target = tau2[(fq, b)]
                            if b not in g.values() and target not in f.values():
                                g[a] = b
                                f[q_next] = target
                                if q_next not in visited:
                                    queue.append(q_next)
                                    visited.add(q_next)
                                found = True
                                break
                        if not found:
                            check = False
                            break

                if not check:
                    break

            # Verify f and g are complete bijections
            if (
                check
                and len(f) == len(Q1)
                and len(g) == len(sigma1)
                and len(set(f.values())) == len(Q1)
                and len(set(g.values())) == len(sigma1)
            ):
                return True, f, g

    return False, None, None

# %% [markdown]
# In part (c) you should assume that in each input automata there is at least one state from which all other states are reachable. You may find the functionality in NetworkX for Strongly Connected Components and Condensations useful for identifying such states.
#
# For isomorphism, you can generate isomorphic DFAs by picking one DFA and applying a random permutation to the states; if you then change a value in the transition function you will likely get non-isomorphic DFAs.
#
# ADD VISUALISER!!!!!!!!!
#
# Choose examples for project report
#
# Discuss to what extent each of these notions of isomorphism preserve synchronization properties of a DFA (if at all).
#
# Up to 2 mins or so

# %%
# TEST 1: same structure, different labels → should return True
A1 = (
    {'p','q','r','s'},
    {'a','b'},
    {
        ('p','a'):'q', ('p','b'):'r',
        ('q','a'):'p', ('q','b'):'s',
        ('r','a'):'s', ('r','b'):'p',
        ('s','a'):'r', ('s','b'):'q'
    },
    'p',
    {'s'}
)

A2 = (
    {'w','x','y','z'},
    {'0','1'},
    {
        ('w','0'):'x', ('w','1'):'y',
        ('x','0'):'w', ('x','1'):'z',
        ('y','0'):'z', ('y','1'):'w',
        ('z','0'):'y', ('z','1'):'x'
    },
    'w',
    {'z'}
)


# TEST 2: different structure → should return False
A3 = (
    {'w','x','y','z'},
    {'0','1'},
    {
        ('w','0'):'x', ('w','1'):'y',
        ('x','0'):'z', ('x','1'):'z',
        ('y','0'):'z', ('y','1'):'z',
        ('z','0'):'z', ('z','1'):'z'
    },
    'w',
    {'z'}
)


# TEST 3: different sizes → should return False
A4 = (
    {'a','b','c','d','e'},
    {'0','1'},
    {
        ('a','0'):'b', ('a','1'):'c',
        ('b','0'):'d', ('b','1'):'a',
        ('c','0'):'a', ('c','1'):'e',
        ('d','0'):'e', ('d','1'):'b',
        ('e','0'):'e', ('e','1'):'e'
    },
    'a',
    {'e'}
)


# RUN TESTS
print("Test 1 (expect True):",  is_semi_isomorphism(A1, A2))
print("Test 2 (expect False):", is_semi_isomorphism(A1, A3))
print("Test 3 (expect False):", is_semi_isomorphism(A1, A4))
print("Test 4 (expect True):",  is_semi_isomorphism(A1, A1))


verdict, f, g = is_semi_isomorphism(A1, A2)
visualise(A1, A2, (verdict, f, g))
# Out:
# Test 1 (expect True): (True, {'s': 'z', 'r': 'x', 'q': 'y', 'p': 'w'}, {'a': '1', 'b': '0'})
# Test 2 (expect False): (False, None, None)
# Test 3 (expect False): (False, None, None)
# Test 4 (expect True): (True, {'s': 's', 'r': 'r', 'q': 'q', 'p': 'p'}, {'a': 'a', 'b': 'b'})
